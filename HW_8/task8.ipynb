# %% [markdown]
# <span style="font-size: 14pt">Домашнее задание №8 </span>
#
# <span style="color: red; font-size: 14pt">Deadline: 20.05.2017 23:59:59</span>
#
# <span style="font-size: 10pt">ФИВТ, АПТ, Курс по машинному обучению, Весна 2017, Модуль Unspervised Learning, </span>
#
# <span style="color:blue; font-size: 10pt">Alexey Romanenko, </span>
# <span style="color:blue; font-size: 10pt; font-family: 'Verdana'">alexromsput@gmail.com</span>

# %% [markdown]
# <h1 align="center">Organization Info</h1>

# %% [markdown]
# **Дополнительный материал для выполнения дз**:
# - Воронцов К. В. Математические методы обучения по прецедентам. 2012. http://www.machinelearning.ru/wiki/images/6/6d/Voron-ML-1.pdf (разделы 5.2 и 7.1)
# - Hastie T., Tibshirani R., Friedman J. The Elements of Statistical Learning. Springer: Data Mining, Inference, and Prediction.  — 2nd ed. — Springer-Verlag. 2009. — 746 p.http://statweb.stanford.edu/~tibs/ElemStatLearn/printings/ESLII_print10.pdf (глава 14)
#
#
#
# **Оформление дз**:
# - Присылайте выполненное задание на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2017_fall <номер_группы> <фамилия>``, к примеру -- ``ML2017_fall 496 ivanov``
# - Выполненное дз сохраните в файл ``<фамилия>_<группа>_task<номер задания>.ipnb``, к примеру -- ``ML2017_496_task1.ipnb``
#
# **Вопросы**:
# - Присылайте вопросы на почту ``ml.course.mipt@gmail.com``
# - Укажите тему письма в следующем формате ``ML2016_fall Question <Содержание вопроса>``
#
# --------
# - **PS1**: Используются автоматические фильтры, и просто не найдем ваше дз, если вы не аккуратно его подпишите.
# - **PS2**: Дедлайн жесткий, в том числе помтоу что это ДЗ последнее в курсе.

# %% [markdown]
# <h1 align="center">Вопросы по теории (30%) </h1>

# %% [markdown]
# ** Задача 1 **
# Ответьте на вопросы:
#
#  1) Как можно не прибегая к визуализации понять, что кластерная структура у данного облака точек отсутствует?
#
#  1*) Можно, например, запустить аггломеративную кластеризацию и построить график: номер_итерации/расстояние_между_сливаемыми_кластерами. Еще есть метод, использующий статистику Хопкинса. Берется и генерируется k точек из равномерного распределения и k точек из нашей выборки, далее считается статистика $H = \frac{\sum w_i}{\sum w_i + \sum u_i}$, где $w_i$ - расстояние от i-той случайной, до ближайшей случайной, а $u_i$ - от i-той из выборки до ближайшей точки из выборки и если эта статистика близка к $\frac{1}{2}$, то наша выборка ~ равномерно распределена в пространстве(класт. структуры нет), ну а если он близок к 0, то можно надеяться на какую-то структуру
#
#  2) Какие из алгоритмов кластеризации могут выделять кластеры с ленточной структурой?
#
#  2*) DBSCAN, Agglomerative Clustering,
#
#  3) Какие алгоритмы кластеризации чувствительны к шуму и перемычкам?
#
#  3*) Kmeans чувствителен к шумам, ведь там считается центр масс набора точек и он будет сильно меняться даже из-за одного выброса. Так же он и будет плох при перемычках. Например, DBSCAN может работать как плохо, так и хорошо, все зависит от того, верно ли подобраны гиперпараметры (все зависит от того, насколько много точек при этих переходах в перемычках)
#
#  4) Каким образом приближают «центр кластера» в нелинейных пространствах?
#
#  4*) В Kernel-Kmeans при подсчете центра масс вместо $x_i$ используется $\varphi(x_i)$ где $\varphi$ - ядро.
#
#  5) Каким образом можно определять число кластеров?
#
#  5*) Смотреть на среднее внутрикластерное расстояние, на среднее расстояние до ближайшего кластера, взять подобие f_measure. Так же есть коэффициент силуэта, с помощью него можно оценить число кластеров
#
# ** Задача 2 **
# Даны пять точек на числовой оси $X = (1; 5; 7; 8; 8)$, число кластеров равно 2. Рассчитайте ответ алгоритма  K-means (финальные центры кластеров), если начальные центры кластеров c1 = 1, c2 = 10.
#
# ANS: (1; 5; 7; 8; 8) -> (0,0,1,1,1). А центры (3, $\frac{23}{3}$)
#
# ** Задача 3 **
# Докажите, что the k-means всегда сходится.
#
# Для начала, докажем, что сумма квадратов расстояний до ближайшего кластера всегда убывает, а из этого уже будет очевидно исходное утверждение. Пусть $A_i$ - наша выборка. X - центр масс, Y - какая-то другая точка, тогда $\sum \overline{YA_i}^2 = \sum <\overline{YA_i},\overline{YA_i}> = \sum <\overline{YX} + \overline{XA_i},\overline{YX} + \overline{XA_i}> = \sum \overline{YX}^2 + \overline{XA_i}^2 + 2<\overline{YX}, \overline{XA_i}> = n\overline{YX}^2 + \sum \overline{XA_i}^2 + 2<\overline{YX}, \sum \overline{XA_i}>$ = / Последняя сумма в скалярном произведении равна нулю, так как Х - центр масс /= $n\overline{YX}^2 + \sum \overline{XA_i}^2 > \sum \overline{XA_i}^2 \blacksquare$
#
# Итак, у нас есть параметр n_clusters = k, также нам известен размер выборки n. Тогда всевозможных разбиений на кластера будет $k^n$. Заметим, что если на i-той и (i + 1)-ой итерации мы получили одно и то же разбиение(то у него получится значение функционала меньше, чем прежде, чего быть не может, -> циклов нет), то разбиение на кластера не будут меняться(так как центры изменяться не будут вообще). А иначе мы будем получать всеглжа разные разбиения, но так как их конечное число, то алгоритм закончится.
#
# ** Задача 4 **
# Для сжатия размерности пространства алгоритм PCA применяется датасету с количеством признаков $D = 100$. Наблюдается следующий спектр собственных значений матрицы объектов-признаков.
# <img src="PCA_lambda.png" width="600">
# Ответье на вопросы
#
# * 1) Высокая ли эффективная размерность пространства признаков (intrinsic dimensionality) (насколько она близка к 100)?
#
# 1*) Так как не наблюдается резкого спада, то лучше вообще не обрезать размерность и оставить ее такой, как она есть(метод крутого сколна)
#
# * 2) Можно ли перевести датасет с помощью PCA в пространство меньшей размерности с минимальными потерями точности?
#
# 2*) Если да, то чему примерно будет равна размернось ну у нас сумма квадратов отклонений будет равна сумме послежних n - k собственных значений. Ну тогда опять же не очень круто убирать хоть сколько то размерностей

# %%
from sklearn.cluster import KMeans

# %% [markdown]
# <h2 align="center">Практическое задание 1 (30%) </h2>
# Реализуйте PCA

# %%
import numpy as np
import pylab as plt
import scipy.linalg
'''
Performs the Principal Coponent analysis of the Matrix F
Matrix must be n * l dimensions
where n is # features
l is # samples
'''

def PCA(F, varRetained = 0.75, show = False):
    # Input
    #     F - initaial matrix 
    # Compute Covariance Matrix Sigma
    # Input
    (n, l) = F.shape
    Sigma = 1.000 / l * F.T.dot(F)
   
    V, d, U = scipy.linalg.svd(F) # TUT BILA BAGA, HOTELI SVD DLYA SIGMI
    print('U {}shape'.format(U.shape))
    print('V {}shape'.format(V.shape))
    # compute the value m: number of minumum features that retains the given variance varRetaine
    dTot = np.sum(d)
    var_i = np.array([np.sum(d[: i + 1]) / \
                dTot * 100.0 for i in range(n)])
    m = np.where(var_i >= varRetained * 100)[0][0] # :(
    print '%.2f %% variance retained in %d dimensions' % (var_i[m], m + 1)

    # plot the variance plot
    if show:
        plt.figure(figsize=(20,14))
        plt.plot(var_i)
        plt.xlabel('Number of Features')
        plt.ylabel(' Percentage Variance retained')
        plt.title('PCA $\% \sigma^2 $ vs # features')
        plt.show()

    # compute the reduced dimensional features by projection
    U_reduced = U[:, :m]
    print('U_red {}shape'.format(U_reduced.shape))
    G = F.dot(U_reduced)

    return G, U_reduced

# %%
# Примените алгоритм к данным MNIST
from sklearn.model_selection import train_test_split

from sklearn.datasets import load_digits
X, y = load_digits(return_X_y=True)
X_train, X_test, Y_train, Y_test = train_test_split(X, y, train_size=0.7)

# %%
X.shape
# Out:
# (1797, 64)

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import random

# %%
plt.figure(figsize=(15,7))
plt.hist(random.sample(range(10000), 123))
plt.show()

# %%
#################################################################
# PCA of training set
print 'Performing PCA - Principal Component Analysis'

Z, U_reduced = PCA(X.T, varRetained = 0.95, show = True)
# Out:
# Performing PCA - Principal COmponent Analysis
# U (1797, 1797)shape
# V (64, 64)shape
# 95.07 % variance retained in 41 dimensions
# U_red (1797, 40)shape

# %%
print Z
print U_reduced
# Out:
# [[  0.00000000e+00   0.00000000e+00   0.00000000e+00 ...,   0.00000000e+00
#     0.00000000e+00   0.00000000e+00]
#  [  3.18542655e+00  -3.77307409e+01  -7.14347740e-01 ...,  -7.82136427e-02
#    -5.87554401e-03  -1.01860415e+00]
#  [  1.50013254e+01  -1.67282116e+02  -2.24880131e+02 ...,  -1.93675764e+01
#     2.15064307e-02  -2.77809415e+00]
#  ...,
#  [  4.58883606e+00  -8.21060355e+01  -1.84385991e+02 ...,  -5.55555807e+01
#     7.27445048e+00  -8.90734326e+00]
#  [ -6.70560338e-01  -2.67762898e+01  -7.19102427e+01 ...,  -1.47027377e+01
#    -2.63634415e+00  -2.42566593e+00]
#  [ -4.09781710e-02  -3.74475690e+00  -1.89588782e+01 ...,   2.53740414e+00
#    -2.39146776e+00   1.38543835e-01]]
# [[ -2.09114372e-02  -2.53199533e-02  -2.54559261e-02 ...,  -2.33223166e-02
#    -2.16829701e-02  -2.37210294e-02]
#  [ -2.10250887e-03   1.38656341e-02   1.21951237e-02 ...,  -2.36086142e-02
#    -5.52694160e-05  -3.65862223e-02]
# ...

# %% [markdown]
# <h1 align="center"><h2 align="center">Практическое задание 2 (40%) </h2> </h1>

# %% [markdown]
# <h2 align="left">Изучение алгоритмов кластеризации на разных выборках</h2>
#
# ### Кластеризация цифр с помощью dbscan
# На данных из sklearn.datasets.load_digits примените алгоритмы кластеризации (знания о метках классов при кластеризации использовать нельзя):
#  - <a href='http://scikit-learn.org/stable/modules/generated/sklearn.cluster.DBSCAN.html#sklearn.cluster.DBSCAN'>dbscan </a>
#  запускайте при различных параметрах eps и minsamples, для всех экспериментов можете выбрать одну метрику (вспомните семинар про  метрические алгоритмы);
#  - Используя метки классов цифр, оцените качество различных кластеризаций при помощи Adjusted Mutual Information и Adjusted Rand Index.
#  - визуалируйте изображения тех цифр, которые соответствуют core_points;
#  - визуалируйте изображения тех цифр, которые соответствуют выбросам;
#  - сделайте выводы и применимости алгоритмов.
#
# ### Уменьшение палитры изображения
#  - для <a href="https://thumbs.dreamstime.com/x/two-lorikeet-birds-2293918.jpg"> картинки </a>
# нужно уменьшить число цветов в палитре; для этого нужно выделить кластеры в пространстве RGB, объекты соответствуют пикселам изображения; после выделения кластеров,
# все пикселы, отнесенные в один кластер, заполняются одним цветом; этот цвет может быть центроидом соответствующего кластера, медианным цветом по кластеру.
#  - Попробуйте различные алгоритмы кластеризации:
#         -- KMeans
#         -- MeanShift
#         -- AgglomerativeClustering
#    Рассмотрите число кластеров K = 2, 3, 10, 20
#  - Для различных кластеризаций оцените и сравните потери от уменьшения цветов при помощи
# метрики <a href="http://scikit-image.org/docs/dev/api/skimage.measure.html"> SSIM</a>. Какой способ оказался лучшим?

# %%
from sklearn.datasets import load_digits

# %%
digits_data = load_digits()

# %%
digits = digits_data.data

# %%
from sklearn.cluster import *

# %%
digits.shape
# Out:
# (1797, 64)

# %%
from sklearn.manifold import TSNE

# %%
tsne = TSNE(n_components=2)
tsne_digits = tsne.fit_transform(digits)

# %%
plt.figure(figsize=(15,10))
plt.scatter(tsne_digits[:,0], tsne_digits[:,1])

# %%
from sklearn.metrics import adjusted_mutual_info_score, adjusted_rand_score

# %%
from color_generator import ColorGenerator

# %%
clrs = []
col_gen = ColorGenerator()
for _ in range(1000):
    clrs.append(col_gen.get_color())
clrs = np.array(clrs)

# %% [markdown]
# Вот размеченная выборка

# %%
21381245
214124
# Out:
# 214124

# %% [markdown]
# ####

# %% [markdown]
# ##

# %%
# plt.figure(figsize=(15,10))
plt.scatter(tsne_digits[:,0], tsne_digits[:,1], c=clrs[digits_data.target])

# %%
## def apply_clustering(estimator, verbosity, **kwargs):
    final_est = estimator(**kwargs)
    estimator_predictions = final_est.fit_predict(digits)
    if(verbosity == True):
        print('AMI is equal to {}'.format(adjusted_mutual_info_score(estimator_predictions,
                                                                     digits_data.target
        )))
        print('AR is equal to {}'.format(adjusted_rand_score(estimator_predictions,
                                                             digits_data.target)))
        plt.figure(figsize=(15,10))
        plt.scatter(tsne_digits[:,0], tsne_digits[:,1], c=clrs[estimator_predictions])
    return final_est, adjusted_mutual_info_score(estimator_predictions, digits_data.target), \
        adjusted_rand_score(estimator_predictions, digits_data.target)

# %%
kmennnn = apply_clustering(KMeans, n_clusters=10)
# Out:
# AMI is equal to 0.734384672928
# AR is equal to 0.664155722479

# %%
apply_clustering(DBSCAN, eps=21) # при таком eps более-менее уже кластеризует
# Out:
# AMI is equal to 0.725188049949
# AR is equal to 0.613922600616
# DBSCAN(algorithm='auto', eps=21, leaf_size=30, metric='euclidean',
#     min_samples=5, n_jobs=1, p=None)

# %%
epsilons = np.linspace(0.5, 50, num = 100)
minsmpls = range(1, 10)

# %%
from itertools import product

# %%
params = list(product(epsilons, minsmpls))

# %%
from tqdm import tqdm

# %%
results
# Out:
# []

# %%
params

# %%
results = []
for cur_eps, cur_min_smpls in tqdm(params):
    results.append(apply_clustering(DBSCAN, verbosity=False, eps=cur_eps, min_samples=cur_min_smpls))
# Out:
# 0it [00:00, ?it/s]
# 1it [00:00,  7.10it/s]
# 3it [00:00,  8.34it/s]
# 5it [00:00,  9.47it/s]
# 7it [00:00, 10.43it/s]
# 9it [00:00, 10.98it/s]
# 11it [00:00, 10.18it/s]
# 13it [00:01, 10.40it/s]
# 15it [00:01, 10.39it/s]
# 17it [00:01, 10.59it/s]
# 19it [00:01,  9.31it/s]
# 21it [00:01,  9.64it/s]
# 22it [00:02,  9.58it/s]
# 24it [00:02,  9.88it/s]
# 26it [00:02, 10.00it/s]
# 28it [00:02,  9.12it/s]
# 29it [00:02,  8.87it/s]
# 30it [00:02,  8.77it/s]
# 31it [00:03,  8.56it/s]
# 32it [00:03,  8.44it/s]
# 33it [00:03,  8.46it/s]
# 34it [00:03,  8.40it/s]
# 35it [00:03,  8.20it/s]
# 36it [00:03,  8.14it/s]
# 37it [00:03,  6.83it/s]
# 38it [00:04,  6.99it/s]
# 39it [00:04,  7.12it/s]
# 40it [00:04,  7.35it/s]
# 41it [00:04,  7.41it/s]
# 42it [00:04,  7.42it/s]
# 43it [00:04,  7.45it/s]
# 44it [00:04,  7.43it/s]
# 45it [00:04,  7.39it/s]
#
# 46it [00:05,  6.32it/s]
# 47it [00:05,  6.39it/s]
# 48it [00:05,  6.57it/s]
# 49it [00:05,  6.57it/s]
# 50it [00:05,  6.59it/s]
# ...

# %%
results = np.array(results)

# %%
np.argmax(results[:,1])
# Out:
# 372

# %%
best_estimator = results[372][0]

# %% [markdown]
# ВОт при таких параметрах получилась наиболее лучшая кластеризация

# %%
list(params)[372]
# Out:
# (21.0, 4)

# %%
plt.figure(figsize=(15,7))
plt.plot(range(len(results)), results[:,1])

# %%
plt.figure(figsize=(15,7))
plt.plot(range(len(results)), results[:,2])

# %%
n

# %%
core_points_ind = best_estimator.core_sample_indices_
noise_points_ind = np.where(best_estimator.labels_ == -1)[0]

# %%
import random

# %%
def draw_rand_core_plus_noise():
    core_ind = random.sample(core_points_ind, 1)[0]
    noise_ind = random.sample(noise_points_ind, 1)[0]
    plt.imshow(digits_data.images[core_ind])
    print('_________________  {}  _________________'.format(digits_data.target[core_ind]))
    plt.show()
    plt.imshow(digits_data.images[noise_ind])
    plt.show()
    print('_________________  {}  _________________'.format(digits_data.target[noise_ind]))

# %%
draw_rand_core_plus_noise()
# Out:
# _________________  9  _________________
# _________________  8  _________________

# %% [markdown]
# # Task ImgClustering

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# Есть еще примеры с другими изображениями в папке

# %%
image = plt.imread('./two-lorikeet-birds-2293918.jpg')

# %%
image.shape
# Out:
# (275, 400, 3)

# %%
plt.figure(figsize=(20, 12))
plt.imshow(image)
plt.show()

# %%
image[0][0]
# Out:
# array([140, 150, 116], dtype=uint8)

# %%
lll = len(image.ravel())
lll
# Out:
# 330000

# %%
img_ravel = image.ravel().reshape(lll / 3, 3)

# %%
img_ravel.shape
# Out:
# (110000, 3)

# %%
import numpy as np

# %%
cluster_numbers = [2,3,10,20, 50, 100, 256]

# %%
from tqdm import tqdm

# %%
from sklearn.cluster import *

# %%
def reduce_dims(estimator):
    return estimator.fit_predict(img_ravel), estimator

# %%
import scipy.misc

# %%
for clust_num in tqdm(cluster_numbers):
    kmen_1000, km_est = reduce_dims(MiniBatchKMeans(n_clusters=clust_num))
    img_reduced = km_est.cluster_centers_[kmen_1000] / 255.
    img_reduced = img_reduced.reshape(image.shape)
    plt.figure(figsize=(20, 12))
    plt.imshow(img_reduced)
    plt.show()
    
    scipy.misc.imsave('ptici{}.jpg'.format(clust_num), img_reduced)
# Out:
# ...
# 100%|██████████| 7/7 [00:13<00:00,  2.91s/it]
