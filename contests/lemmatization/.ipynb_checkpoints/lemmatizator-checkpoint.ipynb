# %%
import numpy as np
import pandas as pd

# %%
import sys

# %%
with open('./task2_lemmas_train') as f:
    train = f.read().splitlines()

# %%
new_vals = []
for elem in train[1:]:
    vals = elem.split(',')[1:]
    for new_el in vals[1:]:
        new_el = new_el.split('+')
        new_vals.append((vals[0], new_el[0], new_el[1]))

# %%
def get_lcp(fst, snd):
    cur_len = 0
    while((cur_len < min(len(fst), len(snd)) and (fst[cur_len] == snd[cur_len]))):
        cur_len += 1
    
    return cur_len

# %%
train = pd.DataFrame(new_vals)
test = pd.read_csv('./task2_lemmas_test')

# %%
train[0] = train[0].apply(lambda elem: elem.decode('utf-8'))
test['X'] = test['X'].apply(lambda elem: elem.decode('utf-8'))

# %%
train.head()
# Out:
#               0            1  2
# 0  vergognerete   vergognare  V
# 1  amnistiavate   amnistiare  V
# 2   menomazione  menomazione  N
# 3    sfaldavamo     sfaldare  V
# 4    sfodererei    sfoderare  V

# %%
from copy import deepcopy

# %%
train_to_get_ez_answers = deepcopy(train)

# %%
to_suff = []
to_resid = []
for word, stemmed in train_to_get_ez_answers[[0,1]].values:
    lenka = get_lcp(word, stemmed)
    to_suff.append(word[lenka:])
    to_resid.append(stemmed[lenka:])
train_to_get_ez_answers['suff'] = to_suff
train_to_get_ez_answers['resid'] = to_resid
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:3: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   This is separate from the ipykernel package so we can avoid doing imports until

# %%
from tqdm import tqdm

# %%
suff_to_res =  train_to_get_ez_answers.groupby('suff')['resid'].apply(set)

# %%
len(train)
# Out:
# 120897

# %%
ez_start[u'\xf9r']
# Out:
# '\xc3\xb9r'

# %%
ez_start = {}
for suff, resid in suff_to_res.iteritems():
    if len(resid) == 1:
        ez_start[suff] = resid.pop()

# %%
ez_given = train_to_get_ez_answers[train_to_get_ez_answers['suff'].isin(ez_start)]
ez_not_given = train_to_get_ez_answers[~train_to_get_ez_answers['suff'].isin(ez_start)]

# %%
len(suff_to_res)
# Out:
# 590

# %%
len(ez_start)
# Out:
# 412

# %%
def get_greatest_suff_to_ez_ans_start(stroka, ez_checker):
    cur_pos = len(stroka) - 1
    best_cur_pos = -1
    while cur_pos >= 0:
        if stroka[cur_pos:] in ez_checker:
            best_cur_pos = cur_pos
        cur_pos -= 1
    if best_cur_pos == -1:
        return -1, ''
    return len(stroka) - best_cur_pos, ez_checker[stroka[best_cur_pos:]]

# %%
ez_given = train_to_get_ez_answers[train_to_get_ez_answers['suff'].isin(ez_start)]
ez_not_given = train_to_get_ez_answers[~train_to_get_ez_answers['suff'].isin(ez_start)]

ez_lenka = []
ez_resid = []
for elem in tqdm(test.X):
    cur_lenka, cur_resid = get_greatest_suff_to_ez_ans_start(elem, ez_start)
    ez_lenka.append(cur_lenka)
    ez_resid.append(cur_resid)
    
    
test['ez_lenka'] = ez_lenka
test['ez_resid'] = ez_resid

test_ez_given = test[test['ez_lenka'] != -1]
test_ez_not_given = test[test['ez_lenka'] == -1]
# Out:
# 100%|██████████| 29661/29661 [00:00<00:00, 277086.16it/s]

# %%
test['ez_lenka'] = ez_lenka
test['ez_resid'] = ez_resid

# %%
ez_start['li']
# Out:
# 'ere'

# %%
test_ez_given = test[test['ez_lenka'] != -1]
test_ez_not_given = test[test['ez_lenka'] == -1]

# %%
test_ez_given.head()
# Out:
#    Id             X  ez_lenka ez_resid
# 1   2   incidentali         2      ere
# 2   3     involtino         3      are
# 3   4         lievi         3      rre
# 5   6   vidimerebbe         5      ere
# 9  10  compassavano         4       re

# %%
ans_ez_given = []
for elem in test_ez_given[['X', 'ez_lenka', 'ez_resid']].values:
    if int(elem[1]) == 0:
        ans_ez_given.append(elem[0] + elem[2].decode('utf-8'))
    else:
        ans_ez_given.append(elem[0][:-int(elem[1])] + elem[2].decode('utf-8'))
        
test_ez_given['label'] = ans_ez_given
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy

# %%
test_ez_given
# Out:
#           Id                 X  ez_lenka ez_resid            label
# 1          2       incidentali         2      ere     incidentaere
# 2          3         involtino         3      are        involtare
# 3          4             lievi         3      rre            lirre
# 5          6       vidimerebbe         5      ere        vidimeere
# 9         10      compassavano         4       re       compassare
# 10        11             cucio         3      ere            cuere
# 15        16     impoverimenti         3       re     impoverimere
# 16        17      smungerebber         6      ere        smungeere
# 18        19    meravigliavano         4       re     meravigliare
# 20        21      sesquipedale         2      ere    sesquipedaere
# 21        22            timide         3    edere         timedere
# 24        25           stimino         3      are          stimare
# 25        26        relazionai         2        e        relazione
# ...

# %%
pos_given_algo =

# %%
diff_lets = set()
for word in train[0]:
     for sym in word:
            diff_lets.add(sym)

# %%
train_clf = train[[0,2]]

# %%
ez_not_given.head()
# Out:
#               0            1  2   suff resid
# 0  vergognerete   vergognare  V  erete   are
# 1  amnistiavate   amnistiare  V   vate    re
# 2   menomazione  menomazione  N
# 4    sfodererei    sfoderare  V   erei   are
# 5    ascondesti    ascondere  V    sti    re

# %%
ez_given.head()
# Out:
#                 0          1  2     suff resid
# 3      sfaldavamo   sfaldare  V     vamo    re
# 6   edifichereste  edificare  V  hereste   are
# 9      computando  computare  V      ndo    re
# 11   diromperanno  dirompere  V     anno     e
# 13     integrando  integrare  V      ndo    re

# %%
test_ez_given.head()
# Out:
#    Id             X  ez_lenka ez_resid         label  vowels  consonal  \
# 1   2   incidentali         2      ere  incidentaere       6         6
# 2   3     involtino         3      are     involtare       4         5
# 3   4         lievi         3      rre         lirre       2         3
# 5   6   vidimerebbe         5      ere     vidimeere       5         4
# 9  10  compassavano         4       re    compassare       4         6
#
#    length  doubles
# 1      12        0
# 2       9        0
# 3       5        1
# 5       9        1
# 9      10        1

# %%
vowels = {'a','e','y','u','i','o', 'A','E','Y','O','U','I', u'\xe0',
 u'\xe8',
 u'\xe9',
 u'\xec',
 u'\xf2',
 u'\xf9'} # мб стоит ё на е заменить везде
consonal = {'q','w','r','t','p','s','d','f','g','h','j','k','l','z','x','c','v','b','n','m'}
consonal |= set(map(lambda let: let.upper(), consonal))
capsed = set(map(lambda let: let.upper(), consonal)) | set(map(lambda let: let.upper(), vowels))

# %%
# ez_given['vowels'] = ez_given[1].apply(lambda elem: len(filter(lambda s: s in vowels, elem)))
# ez_given['consonal'] = ez_given[1].apply(lambda elem: len(filter(lambda s: s in consonal, elem)))

# ez_not_given['vowels'] = ez_not_given[0].apply(lambda elem: len(filter(lambda s: s in vowels, elem)))
# ez_not_given['consonal'] = ez_not_given[0].apply(lambda elem: len(filter(lambda s: s in consonal, elem)))

# test_ez_given['vowels'] = test_ez_given['label'].apply(lambda elem: len(filter(lambda s: s in vowels, elem)))
# test_ez_given['consonal'] = test_ez_given['label'].apply(lambda elem: len(filter(lambda s: s in consonal, elem)))

# test_ez_not_given['vowels'] = test_ez_not_given['X'].apply(lambda elem: len(filter(lambda s: s in vowels, elem)))
# test_ez_not_given['consonal'] = test_ez_not_given['X'].apply(lambda elem: len(filter(lambda s: s in consonal, elem)))

# %%
train_clf['vowels'] = train_clf[0].apply(lambda elem: len(filter(lambda s: s in vowels, elem)))
train_clf['consonal'] = train_clf[0].apply(lambda elem: len(filter(lambda s: s in consonal, elem)))

# train_clf.drop('capsed', axis=1, inplace=True)

# #-----------#
test['vowels'] = test['X'].apply(lambda elem: len(filter(lambda s: s in vowels, elem)))
test['consonal'] = test['X'].apply(lambda elem: len(filter(lambda s: s in consonal, elem)))

# %%
from tqdm import tqdm

# %%
train_clf['length'] = map(len , train_clf[0])
test['length'] = map(len , test['X'])

doblets = []
for surn in tqdm(train_clf[0]):
    dobles = 0
    surn = surn.lower()
    for ind in range(1, len(surn)):
        if surn[ind] == surn[ind - 1]:
            dobles += 1
    doblets.append(dobles)
    
train_clf['doubles'] = doblets 

doblets = []
for surn in tqdm(test['X']):
    dobles = 0
    surn = surn.lower()
    for ind in range(1, len(surn)):
        if surn[ind] == surn[ind - 1]:
            dobles += 1
    doblets.append(dobles)
    
test['doubles'] = doblets
# Out:
# ...
# 100%|██████████| 29661/29661 [00:00<00:00, 258236.52it/s]

# %%
# train_clf['length'] = map(len , train_clf[0])
# test['length'] = map(len , test['X'])

# ez_given['length'] = map(len , ez_given[1])
# ez_not_given['length'] = map(len , ez_not_given[0])

# test_ez_given['length'] = map(len , test_ez_given['label'])
# test_ez_not_given['length'] = map(len , test_ez_not_given['X'])



# doblets = []
# for surn in tqdm(ez_given[1]):
#     dobles = 0
#     surn = surn.lower()
#     for ind in range(1, len(surn)):
#         if surn[ind] == surn[ind - 1]:
#             dobles += 1
#     doblets.append(dobles)
    
# ez_given['doubles'] = doblets 

# doblets = []
# for surn in tqdm(ez_not_given[0]):
#     dobles = 0
#     surn = surn.lower()
#     for ind in range(1, len(surn)):
#         if surn[ind] == surn[ind - 1]:
#             dobles += 1
#     doblets.append(dobles)
    
# ez_not_given['doubles'] = doblets 

# doblets = []
# for surn in tqdm(test_ez_given['label']):
#     dobles = 0
#     surn = surn.lower()
#     for ind in range(1, len(surn)):
#         if surn[ind] == surn[ind - 1]:
#             dobles += 1
#     doblets.append(dobles)
    
# test_ez_given['doubles'] = doblets 

# doblets = []
# for surn in tqdm(test_ez_not_given['X']):
#     dobles = 0
#     surn = surn.lower()
#     for ind in range(1, len(surn)):
#         if surn[ind] == surn[ind - 1]:
#             dobles += 1
#     doblets.append(dobles)
    
# test_ez_not_given['doubles'] = doblets

# %%
import scipy.sparse
from sklearn.preprocessing import PolynomialFeatures

# %%
# sprsed_ez_given = scipy.sparse.csr_matrix(ez_given.drop([0,1,2, 'suff', 'resid'],axis=1).values)
# sprsed_ez_not_given = scipy.sparse.csr_matrix(ez_not_given.drop([0,1,2, 'suff', 'resid'],axis=1).values)

# sprsed_test_ez_given = scipy.sparse.csr_matrix(test_ez_given.drop(['Id', 'X', 'ez_lenka', 'ez_resid', 'label'],axis=1).values)
# sprsed_test_ez_not_given = scipy.sparse.csr_matrix(test_ez_not_given.drop(['Id', 'X', 'ez_lenka', 'ez_resid'],axis=1).values)

# %%
sprsed_train = scipy.sparse.csr_matrix(train_clf.drop([0,2],axis=1).values)
sprsed_test = scipy.sparse.csr_matrix(test.drop(['Id', 'X'],axis=1).values)

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
# ngram_vectorizer_ez_given = CountVectorizer(analyzer='char_wb', ngram_range=(2, 6)) 
# ngram_vectorizer_ez_given.fit(ez_given[1]) 

# ngram_vectorizer_ez_not_given = CountVectorizer(analyzer='char_wb', ngram_range=(2, 6)) 
# ngram_vectorizer_ez_not_given.fit(ez_not_given[0])
# Out:
# CountVectorizer(analyzer='char_wb', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(2, 6), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
ngram_vectorizer = CountVectorizer(analyzer='char_wb', ngram_range=(2, 6)) 
ngram_vectorizer.fit(train[0])
# Out:
# CountVectorizer(analyzer='char_wb', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(2, 6), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
# ngram_ez_given = ngram_vectorizer_ez_given.transform(ez_given[1])
# ngram_ez_not_given = ngram_vectorizer_ez_not_given.transform(ez_not_given[0])

# ngram_test_ez_given = ngram_vectorizer_ez_given.transform(test_ez_given['label'])
# ngram_test_ez_not_given = ngram_vectorizer_ez_not_given.transform(test_ez_not_given['X'])

# %%
ngram_train = ngram_vectorizer.transform(train[0])
ngram_test = ngram_vectorizer.transform(test['X'])

# %%
# # ngram_train = ngram_vectorizer.transform(train[0])


# all_sparsed_ez_given = scipy.sparse.bmat([[ngram_ez_given, sprsed_ez_given]], format='csr')
# all_sparsed_ez_not_given = scipy.sparse.bmat([[ngram_ez_not_given, sprsed_ez_not_given]], format='csr')


# # all_sparsed_tr.shape, all_sparsed_te.shape


# all_sparsed_test_ez_given = scipy.sparse.bmat([[ngram_test_ez_given, sprsed_test_ez_given]], format='csr')
# all_sparsed_test_ez_not_given = scipy.sparse.bmat([[ngram_test_ez_not_given, sprsed_test_ez_not_given]], format='csr')


# # all_sparsed_tr.shape, all_sparsed_te.shape

# %%
# ngram_train = ngram_vectorizer.transform(train[0])



all_sparsed_tr = scipy.sparse.bmat([[ngram_train, sprsed_train]], format='csr')
all_sparsed_te = scipy.sparse.bmat([[ngram_test, sprsed_test]], format='csr')


all_sparsed_tr.shape, all_sparsed_te.shape
# Out:
# ((120897, 166200), (29661, 166200))

# %%
from sklearn.linear_model import LogisticRegression

# %% [raw]
# fst yeezy 0.914429877166
# 2-4 0.938169485918
# 2-5 0.945820753546
# 2-6 0.946275693784

# %%
train.head()
# Out:
#               0            1  2
# 0  vergognerete   vergognare  V
# 1  amnistiavate   amnistiare  V
# 2   menomazione  menomazione  N
# 3    sfaldavamo     sfaldare  V
# 4    sfodererei    sfoderare  V

# %%
# algo_1_ez_given = LogisticRegression(C=.55).fit(all_sparsed_tr, train[2])
# pos_predicted = algo_1.predict(all_sparsed_te)
# algo_1_ez_not_given = LogisticRegression(C=.55).fit(all_sparsed_tr, train[2])
# pos_predicted = algo_1.predict(all_sparsed_te)

# %%
algo_1 = LogisticRegression(C=.65).fit(all_sparsed_tr, train[2])
pos_predicted = algo_1.predict(all_sparsed_te)

# %%
test[2] = pos_predicted

# %%
pd.Series(pos_predicted).value_counts()
# Out:
# V    24379
# A     3183
# N     2099
# dtype: int64

# %%
all_sparsed_ez_given
# Out:
# <15951x37060 sparse matrix of type '<type 'numpy.int64'>'
# 	with 738035 stored elements in Compressed Sparse Row format>

# %%
# ngram_vectorizer = CountVectorizer(analyzer='char_wb', ngram_range=(2, 3), min_df=1) 
# ngram_train = ngram_vectorizer.fit_transform(train.surname) 

from sklearn.cross_validation import train_test_split 
from sklearn.metrics import accuracy_score 
from sklearn import linear_model 


X_train, X_test, Y_train, Y_test = train_test_split(all_sparsed_tr, train_clf[2], train_size=.8, random_state=42, stratify=train_clf[2]) 
lr = LogisticRegression(C=.65).fit(X_train, Y_train) 
print (accuracy_score(Y_test, lr.predict(X_test)))
# Out:
# 0.946195202647

# %%
0.945326716294,
# Out:
# (0.945326716294,)

# %%
train_lem = train_clf.drop(2, axis=1)

# %%
train_lem
# Out:
#                           0  vowels  consonal  length  doubles
# 0              vergognerete       5         7      12        0
# 1              amnistiavate       6         6      12        0
# 2               menomazione       6         5      11        0
# 3                sfaldavamo       4         6      10        0
# 4                sfodererei       5         5      10        0
# 5                ascondesti       4         6      10        0
# 6             edifichereste       6         7      13        0
# 7                maschieran       4         6      10        0
# 8             transennasser       4         9      13        2
# 9                computando       4         6      10        0
# 10               accudisser       4         6      10        2
# 11             diromperanno       5         7      12        1
# 12            intercollegai       6         7      13        1
# 13               integrando       4         6      10        0
# ...

# %%
train_lem[1] = train[1]

# %%
train_lem[2] = train[2]

# %%
train_lem
# Out:
#                           0  vowels  consonal  length  doubles  \
# 0              vergognerete       5         7      12        0
# 1              amnistiavate       6         6      12        0
# 2               menomazione       6         5      11        0
# 3                sfaldavamo       4         6      10        0
# 4                sfodererei       5         5      10        0
# 5                ascondesti       4         6      10        0
# 6             edifichereste       6         7      13        0
# 7                maschieran       4         6      10        0
# 8             transennasser       4         9      13        2
# 9                computando       4         6      10        0
# 10               accudisser       4         6      10        2
# 11             diromperanno       5         7      12        1
# 12            intercollegai       6         7      13        1
# 13               integrando       4         6      10        0
# ...

# %%
v_tra_lem = train_lem[train_lem[2] == 'V']
a_tra_lem = train_lem[train_lem[2] == 'A']
n_tra_lem = train_lem[train_lem[2] == 'N']

# %%
v_tra_lem.drop(2,axis=1, inplace=True)
a_tra_lem.drop(2,axis=1, inplace=True)
n_tra_lem.drop(2,axis=1, inplace=True)
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# ...

# %%
def get_lcp(fst, snd):
    cur_len = 0
    while((cur_len < min(len(fst), len(snd)) and (fst[cur_len] == snd[cur_len]))):
        cur_len += 1
    
    return cur_len

# %%
get_lcp('asdwq', '1337')
# Out:
# 0

# %%
test.head()
# Out:
#    Id                X  vowels  consonal  length  doubles
# 0   1         gettonan       3         5       8        1
# 1   2      incidentali       5         6      11        0
# 2   3        involtino       4         5       9        0
# 3   4            lievi       3         2       5        0
# 4   5  comunistizzasse       6         9      15        2

# %%
v_tra_lem.head()
# Out:
#               0  vowels  consonal  length  doubles           1
# 0  vergognerete       5         7      12        0  vergognare
# 1  amnistiavate       6         6      12        0  amnistiare
# 3    sfaldavamo       4         6      10        0    sfaldare
# 4    sfodererei       5         5      10        0   sfoderare
# 5    ascondesti       4         6      10        0   ascondere

# %%
to_add = []
to_add_ = []
to_pref = []
to_suff = []
for word, stemmed in v_tra_lem[[0,1]].values:
    lenka = get_lcp(word, stemmed)
    to_add.append(stemmed[lenka:])
    to_pref.append(word[:lenka])
    to_suff.append(word[lenka:])
    to_add_.append(len(word) - lenka)
v_tra_lem['resid'] = to_add
v_tra_lem['pref'] = to_pref
v_tra_lem['suff'] = to_suff
v_tra_lem['lenka'] = to_add_
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# ...

# %%
to_add = []
to_add_ = []
to_pref = []
to_suff = []
for word, stemmed in a_tra_lem[[0,1]].values:
    lenka = get_lcp(word, stemmed)
    to_add.append(stemmed[lenka:])
    to_pref.append(word[:lenka])
    to_suff.append(word[lenka:])
    to_add_.append(len(word) - lenka)
a_tra_lem['resid'] = to_add
a_tra_lem['pref'] = to_pref
a_tra_lem['suff'] = to_suff
a_tra_lem['lenka'] = to_add_
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:3: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
to_add = []
to_add_ = []
to_pref = []
to_suff = []
for word, stemmed in n_tra_lem[[0,1]].values:
    lenka = get_lcp(word, stemmed)
    to_add.append(stemmed[lenka:])
    to_pref.append(word[:lenka])
    to_suff.append(word[lenka:])
    to_add_.append(len(word) - lenka)
n_tra_lem['resid'] = to_add
n_tra_lem['pref'] = to_pref
n_tra_lem['suff'] = to_suff
n_tra_lem['lenka'] = to_add_
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:3: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   This is separate from the ipykernel package so we can avoid doing imports until
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:11: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # This is added back by InteractiveShellApp.init_path()
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
grupped_v = v_tra_lem.groupby('suff')['resid'].apply(set)
grupped_a = a_tra_lem.groupby('suff')['resid'].apply(set)
grupped_n = n_tra_lem.groupby('suff')['resid'].apply(set)

# %%
print(len(filter(lambda elem: len(elem) == 1,grupped_v)) / float(len(grupped_v)))
print len(filter(lambda elem: len(elem) == 1,grupped_a)) / float(len(grupped_a))
print len(filter(lambda elem: len(elem) == 1,grupped_n)) / float(len(grupped_n))
# Out:
# 0.672514619883
# 0.741935483871
# 0.940298507463

# %%
from collections import defaultdict

# %%
ez_suff_v = {}
ez_suff_a = {}
ez_suff_n = {}

for suff, resid in grupped_v.iteritems():
    if len(resid) == 1:
        ez_suff_v[suff] = resid.pop()
        
for suff, resid in grupped_a.iteritems():
    if len(resid) == 1:
        ez_suff_a[suff] = resid.pop()
        
for suff, resid in grupped_n.iteritems():
    if len(resid) == 1:
        ez_suff_n[suff] = resid.pop()

# %%
from sklearn.feature_extraction.text import CountVectorizer

# %%
from sklearn.preprocessing import PolynomialFeatures

# %%
def get_greatest_suff_to_ez_ans_start(stroka, ez_checker):
    cur_pos = len(stroka) - 1
    best_cur_pos = -1
    while cur_pos >= 0:
        if stroka[cur_pos:] in ez_checker:
            best_cur_pos = cur_pos
        cur_pos -= 1
    if best_cur_pos == -1:
        return -1, ''
    return len(stroka) - best_cur_pos, ez_checker[stroka[best_cur_pos:]]

# %%
# pf = PolynomialFeatures(degree=2,interaction_only=True)
# ntrrrr = pd.DataFrame(pf.fit_transform(n_tra_lem.drop([0,1, 'resid'],axis=1).values))

# %%
test_v = test[test[2] == 'V']
test_a = test[test[2] == 'A']
test_n = test[test[2] == 'N']

# %%
ez_lenka = []
ez_resid = []
for elem in tqdm(test_v['X']):
    cur_lenka, cur_resid = get_greatest_suff_to_ez_ans_start(elem, ez_suff_v)
    ez_lenka.append(cur_lenka)
    ez_resid.append(cur_resid)
    
test_v['ez_lenka'] = ez_lenka
test_v['ez_resid'] = ez_resid
    
ez_lenka = []
ez_resid = []
for elem in tqdm(test_a['X']):
    cur_lenka, cur_resid = get_greatest_suff_to_ez_ans_start(elem, ez_suff_a)
    ez_lenka.append(cur_lenka)
    ez_resid.append(cur_resid)
    
test_a['ez_lenka'] = ez_lenka
test_a['ez_resid'] = ez_resid
    
ez_lenka = []
ez_resid = []
for elem in tqdm(test_n['X']):
    cur_lenka, cur_resid = get_greatest_suff_to_ez_ans_start(elem, ez_suff_n)
    ez_lenka.append(cur_lenka)
    ez_resid.append(cur_resid)
    
test_n['ez_lenka'] = ez_lenka
test_n['ez_resid'] = ez_resid
# Out:
# 100%|██████████| 24379/24379 [00:00<00:00, 339469.40it/s]
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if __name__ == '__main__':
# 100%|██████████| 3183/3183 [00:00<00:00, 165324.75it/s]
# ...

# %%
a_tra_lem['target'] = a_tra_lem['resid'] + '+' + map(str,(a_tra_lem['lenka']))
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
n_tra_lem['target'] = n_tra_lem['resid'] + '+' + map(str,(n_tra_lem['lenka']))
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
v_tra_lem['target'] = v_tra_lem['resid'] + '+' + map(str,(v_tra_lem['lenka']))
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
# pf = PolynomialFeatures(degree=2,interaction_only=True)
# ntrrrr = pd.DataFrame(pf.fit_transform(n_tra_lem.drop([0,1, 'resid', 'lenka', 'pref', 'target'],axis=1).values))

# %%
ez_given_v = v_tra_lem[v_tra_lem['suff'].isin(ez_suff_v)]
ez_not_given_v = v_tra_lem[~v_tra_lem['suff'].isin(ez_suff_v)]

ez_lenka = []
ez_resid = []
for elem in tqdm(test_v.X):
    cur_lenka, cur_resid = get_greatest_suff_to_ez_ans_start(elem, ez_suff_v)
    ez_lenka.append(cur_lenka)
    ez_resid.append(cur_resid)
    
    
test_v['ez_lenka'] = ez_lenka
test_v['ez_resid'] = ez_resid

test_ez_given_v = test_v[test_v['ez_lenka'] != -1]
test_ez_not_given_v = test_v[test_v['ez_lenka'] == -1]
# Out:
# 100%|██████████| 24379/24379 [00:00<00:00, 182936.23it/s]
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
ez_given_a = a_tra_lem[a_tra_lem['suff'].isin(ez_suff_a)]
ez_not_given_a = a_tra_lem[~a_tra_lem['suff'].isin(ez_suff_a)]

ez_lenka = []
ez_resid = []
for elem in tqdm(test_a.X):
    cur_lenka, cur_resid = get_greatest_suff_to_ez_ans_start(elem, ez_suff_a)
    ez_lenka.append(cur_lenka)
    ez_resid.append(cur_resid)
    
    
test_a['ez_lenka'] = ez_lenka
test_a['ez_resid'] = ez_resid

test_ez_given_a = test_a[test_a['ez_lenka'] != -1]
test_ez_not_given_a = test_a[test_a['ez_lenka'] == -1]
# Out:
# 100%|██████████| 3183/3183 [00:00<00:00, 152026.03it/s]
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
ez_given_n = n_tra_lem[n_tra_lem['suff'].isin(ez_suff_n)]
ez_not_given_n = n_tra_lem[~n_tra_lem['suff'].isin(ez_suff_n)]

ez_lenka = []
ez_resid = []
for elem in tqdm(test_n.X):
    cur_lenka, cur_resid = get_greatest_suff_to_ez_ans_start(elem, ez_suff_n)
    ez_lenka.append(cur_lenka)
    ez_resid.append(cur_resid)
    
    
test_n['ez_lenka'] = ez_lenka
test_n['ez_resid'] = ez_resid

test_ez_given_n = test_n[test_n['ez_lenka'] != -1]
test_ez_not_given_n = test_n[test_n['ez_lenka'] == -1]
# Out:
# 100%|██████████| 2099/2099 [00:00<00:00, 156432.13it/s]
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   if sys.path[0] == '':
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   del sys.path[0]

# %%
ans_ez_given = []
for elem in test_ez_given_v[['X', 'ez_lenka', 'ez_resid']].values:
    if int(elem[1]) == 0:
        ans_ez_given.append(elem[0] + elem[2].decode('utf-8'))
    else:
        ans_ez_given.append(elem[0][:-int(elem[1])] + elem[2].decode('utf-8'))
        
test_ez_given_v['label'] = ans_ez_given

ans_ez_given = []
for elem in test_ez_given_a[['X', 'ez_lenka', 'ez_resid']].values:
    if int(elem[1]) == 0:
        ans_ez_given.append(elem[0] + elem[2].decode('utf-8'))
    else:
        ans_ez_given.append(elem[0][:-int(elem[1])] + elem[2].decode('utf-8'))
        
test_ez_given_a['label'] = ans_ez_given

ans_ez_given = []
for elem in test_ez_given_n[['X', 'ez_lenka', 'ez_resid']].values:
    if int(elem[1]) == 0:
        ans_ez_given.append(elem[0] + elem[2].decode('utf-8'))
    else:
        ans_ez_given.append(elem[0][:-int(elem[1])] + elem[2].decode('utf-8'))
        
test_ez_given_n['label'] = ans_ez_given
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:17: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:26: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
test_ez_given_a.head()
# Out:
#       Id             X  vowels  consonal  length  doubles  2  ez_lenka  \
# 51    52         secca       2         3       5        1  A         1
# 71    72    fornitrici       4         6      10        0  A         4
# 84    85   biascicante       5         6      11        0  A         3
# 106  107     decadente       4         5       9        0  A         3
# 117  118  elaboratrici       6         6      12        0  A         4
#
#     ez_resid        label
# 51         o        secco
# 71       ore    fornitore
# 84        re   biascicare
# 106       re     decadere
# 117      ore  elaboratore

# %%
ez_not_given_v.head()
# Out:
#               0  vowels  consonal  length  doubles           1 resid  \
# 0  vergognerete       5         7      12        0  vergognare   are
# 1  amnistiavate       6         6      12        0  amnistiare    re
# 4    sfodererei       5         5      10        0   sfoderare   are
# 5    ascondesti       4         6      10        0   ascondere    re
# 7    maschieran       4         6      10        0   maschiare   are
#
#        pref   suff  lenka target
# 0   vergogn  erete      5  are+5
# 1  amnistia   vate      4   re+4
# 4    sfoder   erei      4  are+4
# 5   asconde    sti      3   re+3
# 7    maschi   eran      4  are+4

# %%
test_ez_not_given_a.head()
# Out:
#     Id             X  vowels  consonal  length  doubles  2  ez_lenka ez_resid
# 1    2   incidentali       5         6      11        0  A        -1
# 20  21  sesquipedale       6         6      12        0  A        -1
# 21  22        timide       3         3       6        0  A        -1
# 44  45       plurale       3         4       7        0  A        -1
# 58  59  scomponibili       5         7      12        0  A        -1

# %%
sprsed_train_a = scipy.sparse.csr_matrix(ez_not_given_a.drop([0,1, 'resid', 'lenka', 'pref', 'suff', 'target'],axis=1).values)
sprsed_train_n = scipy.sparse.csr_matrix(ez_not_given_n.drop([0,1, 'resid', 'lenka', 'pref', 'suff', 'target'],axis=1).values)
sprsed_train_v = scipy.sparse.csr_matrix(ez_not_given_v.drop([0,1, 'resid', 'lenka', 'pref', 'suff', 'target'],axis=1).values)

sprsed_test_a = scipy.sparse.csr_matrix(test_ez_not_given_a.drop([2, 'Id', 'X', 'ez_lenka', 'ez_resid'],axis=1).values)
sprsed_test_n = scipy.sparse.csr_matrix(test_ez_not_given_n.drop([2, 'Id', 'X', 'ez_lenka', 'ez_resid'],axis=1).values)
sprsed_test_v = scipy.sparse.csr_matrix(test_ez_not_given_v.drop([2, 'Id', 'X', 'ez_lenka', 'ez_resid'],axis=1).values)





# ngram_vectorizer = CountVectorizer(analyzer='char_wb', ngram_range=(2, 5), min_df=1) 
# ngram_vectorizer.fit(a_tra_lem[0])

# %%
ngram_vectorizer_a = CountVectorizer(analyzer='char_wb', ngram_range=(2, 5), min_df=1) 
ngram_vectorizer_a.fit(ez_not_given_a[0])

ngram_vectorizer_n = CountVectorizer(analyzer='char_wb', ngram_range=(2, 5), min_df=1) 
ngram_vectorizer_n.fit(ez_not_given_n[0])

ngram_vectorizer_v = CountVectorizer(analyzer='char_wb', ngram_range=(2, 6), min_df=1) 
ngram_vectorizer_v.fit(ez_not_given_v[0])
# Out:
# CountVectorizer(analyzer='char_wb', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(2, 6), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
ngram_train_a = ngram_vectorizer_a.transform(ez_not_given_a[0])
ngram_train_n = ngram_vectorizer_n.transform(ez_not_given_n[0])
ngram_train_v = ngram_vectorizer_v.transform(ez_not_given_v[0])

ngram_test_a = ngram_vectorizer_a.transform(test_ez_not_given_a['X'])
ngram_test_n = ngram_vectorizer_n.transform(test_ez_not_given_n['X'])
ngram_test_v = ngram_vectorizer_v.transform(test_ez_not_given_v['X'])

# %%
all_sparsed_tr_a = scipy.sparse.bmat([[ngram_train_a, sprsed_train_a]], format='csr')
all_sparsed_tr_n = scipy.sparse.bmat([[ngram_train_n, sprsed_train_n]], format='csr')
all_sparsed_tr_v = scipy.sparse.bmat([[ngram_train_v, sprsed_train_v]], format='csr')


all_sparsed_te_a = scipy.sparse.bmat([[ngram_test_a, sprsed_test_a]], format='csr')

all_sparsed_te_n = scipy.sparse.bmat([[ngram_test_n, sprsed_test_n]], format='csr')

all_sparsed_te_v = scipy.sparse.bmat([[ngram_test_v, sprsed_test_v]], format='csr')

# %%
from sklearn.linear_model import LogisticRegression

# %% [markdown]
# labels_for_a&n

# %%
# %%time
algo_2_a = LogisticRegression(C=.65).fit(all_sparsed_tr_a, ez_not_given_a['target'])
label_predicted_a = algo_2_a.predict(all_sparsed_te_a)
# Out:
# CPU times: user 2.04 s, sys: 14.5 ms, total: 2.05 s
# Wall time: 2.06 s

# %%
# %%time
algo_2_n = LogisticRegression(C=.65).fit(all_sparsed_tr_n, ez_not_given_n['target'])
label_predicted_n = algo_2_n.predict(all_sparsed_te_n)
# Out:
# CPU times: user 2.07 s, sys: 14.1 ms, total: 2.09 s
# Wall time: 2.09 s

# %% [markdown]
# --------------
# FOr V, start with predicting len, and than we'll bredict resid

# %%
algo_lenka_v = LogisticRegression(C=.65).fit(all_sparsed_tr_v, ez_not_given_v['lenka'])
lenka_predicted_v = algo_lenka_v.predict(all_sparsed_te_v)

# %%
vvvv_test = test_ez_not_given_v

# %%
vvvv_test['lenka'] = lenka_predicted_v
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
train_lem
# Out:
#                           0  vowels  consonal  length  doubles  \
# 0              vergognerete       5         7      12        0
# 1              amnistiavate       6         6      12        0
# 2               menomazione       6         5      11        0
# 3                sfaldavamo       4         6      10        0
# 4                sfodererei       5         5      10        0
# 5                ascondesti       4         6      10        0
# 6             edifichereste       6         7      13        0
# 7                maschieran       4         6      10        0
# 8             transennasser       4         9      13        2
# 9                computando       4         6      10        0
# 10               accudisser       4         6      10        2
# 11             diromperanno       5         7      12        1
# 12            intercollegai       6         7      13        1
# 13               integrando       4         6      10        0
# ...

# %%
ez_not_given_v
# Out:
#                           0  vowels  consonal  length  doubles  \
# 0              vergognerete       5         7      12        0
# 1              amnistiavate       6         6      12        0
# 4                sfodererei       5         5      10        0
# 5                ascondesti       4         6      10        0
# 7                maschieran       4         6      10        0
# 8             transennasser       4         9      13        2
# 10               accudisser       4         6      10        2
# 12            intercollegai       6         7      13        1
# 14            sbramerebbero       5         8      13        1
# 16           oltrepassasser       5         9      14        2
# 17              cauzionavan       6         5      11        0
# 18              scarrozzata       4         7      11        2
# 19           intossicassero       6         8      14        2
# 20                 incurvan       3         5       8        0
# ...

# %%
to_add = []
for word, stemmed in ez_not_given_v[[0,1]].values:
    to_add.append(stemmed[get_lcp(word, stemmed):])

ez_not_given_v['resid'] = to_add
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """

# %%
to_pref = []
for word, lenka in vvvv_test[['X', 'lenka']].values:
    to_pref.append(word[:len(word) - lenka])
vvvv_test['pref'] = to_pref
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   after removing the cwd from sys.path.

# %%
vvvv_test.head()
# Out:
#    Id                X  vowels  consonal  length  doubles  2  ez_lenka  \
# 0   1         gettonan       3         5       8        1  V        -1
# 4   5  comunistizzasse       6         9      15        2  V        -1
# 6   7         imbrodan       3         5       8        0  V        -1
# 7   8         strillar       2         6       8        1  V        -1
# 8   9         cifrasti       3         5       8        0  V        -1
#
#   ez_resid  lenka          pref
# 0               1       gettona
# 4               3  comunistizza
# 6               1       imbroda
# 7               0      strillar
# 8               3         cifra

# %%
sprsed_vvv =scipy.sparse.csr_matrix(vvvv_test.drop([2, 'Id', 'X', 'pref', 'lenka', 'ez_lenka', 'ez_resid'],axis=1).values)

# %%
ngram_vectorizer_a = CountVectorizer(analyzer='char_wb', ngram_range=(2, 6), min_df=1) 
ngram_vectorizer_a.fit(ez_not_given_v['pref'])
# Out:
# CountVectorizer(analyzer='char_wb', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(2, 6), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
ngram_train_vvvvvvv = ngram_vectorizer_a.transform(ez_not_given_v['pref'])

ngram_test_vvvvvvv = ngram_vectorizer_a.transform(vvvv_test['pref'])

# %%
all_sparsed_tr_vvvv = scipy.sparse.bmat([[ngram_train_vvvvvvv, sprsed_train_v]], format='csr')



all_sparsed_te_vvvv = scipy.sparse.bmat([[ngram_test_vvvvvvv, sprsed_vvv]], format='csr')

# %%
resid_algo = LogisticRegression(C=.65).fit(all_sparsed_tr_vvvv, ez_not_given_v['resid'])
resid_predicted = resid_algo.predict(all_sparsed_te_vvvv)

# %%
resid_predicted
# Out:
# array(['re', 're', 're', ..., 're', 'are', 're'], dtype=object)

# %%
ansa = pd.DataFrame()

# %%
ansa['Id'] = test['Id']
ansa['pos'] = pos_predicted

# %%
ansa
# Out:
#           Id pos
# 0          1   V
# 1          2   A
# 2          3   V
# 3          4   N
# 4          5   V
# 5          6   V
# 6          7   V
# 7          8   V
# 8          9   V
# 9         10   V
# 10        11   V
# 11        12   V
# 12        13   V
# 13        14   V
# 14        15   V
# 15        16   N
# 16        17   V
# 17        18   V
# 18        19   V
# 19        20   V
# 20        21   A
# 21        22   A
# 22        23   V
# 23        24   V
# 24        25   V
# 25        26   V
# 26        27   V
# 27        28   V
# 28        29   V
# 29        30   V
# ...      ...  ..
# 29631  29632   V
# 29632  29633   V
# 29633  29634   N
# 29634  29635   V
# 29635  29636   V
# 29636  29637   V
# 29637  29638   V
# 29638  29639   V
# 29639  29640   V
# 29640  29641   V
# 29641  29642   V
# 29642  29643   N
# 29643  29644   V
# 29644  29645   V
# 29645  29646   V
# 29646  29647   V
# 29647  29648   V
# 29648  29649   V
# 29649  29650   N
# 29650  29651   V
# ...

# %%
label_predicted_a[0]
# Out:
# 'e+1'

# %%
label_predicted_a[0]
# Out:
# 'e+1'

# %%
del to_merge_all

# %%
test_ez_given_a.head()
# Out:
#       Id             X  vowels  consonal  length  doubles  2  ez_lenka  \
# 51    52         secca       2         3       5        1  A         1
# 71    72    fornitrici       4         6      10        0  A         4
# 84    85   biascicante       5         6      11        0  A         3
# 106  107     decadente       4         5       9        0  A         3
# 117  118  elaboratrici       6         6      12        0  A         4
#
#     ez_resid        label
# 51         o        secco
# 71       ore    fornitore
# 84        re   biascicare
# 106       re     decadere
# 117      ore  elaboratore

# %%
test_ez_not_given_a.head()
# Out:
#     Id             X  vowels  consonal  length  doubles  2  ez_lenka ez_resid
# 1    2   incidentali       5         6      11        0  A        -1
# 20  21  sesquipedale       6         6      12        0  A        -1
# 21  22        timide       3         3       6        0  A        -1
# 44  45       plurale       3         4       7        0  A        -1
# 58  59  scomponibili       5         7      12        0  A        -1

# %%
test_ez_given_a.head()
# Out:
#       Id             X  vowels  consonal  length  doubles  2  ez_lenka  \
# 51    52         secca       2         3       5        1  A         1
# 71    72    fornitrici       4         6      10        0  A         4
# 84    85   biascicante       5         6      11        0  A         3
# 106  107     decadente       4         5       9        0  A         3
# 117  118  elaboratrici       6         6      12        0  A         4
#
#     ez_resid        label
# 51         o        secco
# 71       ore    fornitore
# 84        re   biascicare
# 106       re     decadere
# 117      ore  elaboratore

# %%
test_ez_given_n.head()
# Out:
#       Id              X  vowels  consonal  length  doubles  2  ez_lenka  \
# 90    91         viados       3         3       6        0  N         1
# 116  117  sessantottini       5         8      13        2  N         3
# 254  255     ortodossia       5         5      10        1  N         1
# 266  267      juventina       4         5       9        0  N         1
# 272  273        mistura       3         4       7        0  N         1
#
#     ez_resid        label
# 90                  viado
# 116        o  sessantotto
# 254        o   ortodossio
# 266        o    juventino
# 272        o      misturo

# %%
lenkivatvet = []


for ind , elem in enumerate(test_ez_not_given_a['Id'].values):
    residka, lena = label_predicted_a[ind].split('+')
    lenkivatvet.append((elem, lena, residka))
    
for ind , elem in enumerate(test_ez_not_given_n['Id'].values):
    residka, lena = label_predicted_n[ind].split('+')
    lenkivatvet.append((elem, lena, residka))
    
for elem in to_merge_vvv:
    lenkivatvet.append(elem)
    
for elem , lena, residka in (test_ez_given_a[['Id', 'ez_lenka', 'ez_resid']].values):
#     residka, lena = label_predicted_a[ind].split('+')
    lenkivatvet.append((elem, lena, residka))
    
for elem , lena, residka in (test_ez_given_n[['Id', 'ez_lenka', 'ez_resid']].values):
#     residka, lena = label_predicted_n[ind].split('+')
    lenkivatvet.append((elem, lena, residka))
    
for elem , lena, residka in (test_ez_given_v[['Id', 'ez_lenka', 'ez_resid']].values):
#     residka, lena = label_predicted_n[ind].split('+')
    lenkivatvet.append((elem, lena, residka))

# %%
to_merge_all = pd.DataFrame(lenkivatvet)

# %%
to_merge_all.sort_values(0, inplace=True)

# %%
fenal = to_merge_all
fenal['X'] = test['X'].values

# %%
fenal.head()
# Out:
#        0  1    2                X
# 3112   1  1   re         gettonan
# 0      2  1    e      incidentali
# 18307  3  3  are        involtino
# 1459   4  1    o            lievi
# 3113   5  3   re  comunistizzasse

# %%
elem
# Out:
# 29661

# %%
elem
# Out:
# 29661

# %%
print elem[2][:-int(elem[0])] + elem[1].decode('utf-8')
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-308-cc1dae566217> in <module>()
# ----> 1 print elem[2][:-int(elem[0])] + elem[1].decode('utf-8')
#
# TypeError: 'int' object has no attribute '__getitem__'

# %%
elem[2][:0]
# Out:
# u''

# %%
fenal.head()
# Out:
#        0  1    2                X
# 3112   1  1   re         gettonan
# 0      2  1    e      incidentali
# 18307  3  3  are        involtino
# 1459   4  1    o            lievi
# 3113   5  3   re  comunistizzasse

# %%
fenal_ansa = []
for elem in fenal[[1, 2, 'X']].values:
    if int(elem[0]) == 0:
        fenal_ansa.append(elem[2] + elem[1].decode('utf-8'))
    else:
        fenal_ansa.append(elem[2][:-int(elem[0])] + elem[1].decode('utf-8'))

# %%
rili_final = fenal
rili_final['nf'] = fenal_ansa
rili_final['pos'] = ansa['pos'].values

# %%
test
# Out:
#           Id                 X  vowels  consonal  length  doubles  2
# 0          1          gettonan       3         5       8        1  V
# 1          2       incidentali       5         6      11        0  A
# 2          3         involtino       4         5       9        0  V
# 3          4             lievi       3         2       5        0  N
# 4          5   comunistizzasse       6         9      15        2  V
# 5          6       vidimerebbe       5         6      11        1  V
# 6          7          imbrodan       3         5       8        0  V
# 7          8          strillar       2         6       8        1  V
# 8          9          cifrasti       3         5       8        0  V
# 9         10      compassavano       5         7      12        1  V
# 10        11             cucio       3         2       5        0  V
# 11        12        snobbavate       4         6      10        1  V
# 12        13          tesseron       3         5       8        1  V
# ...

# %%
rili_final['label'] = rili_final['nf'] + '+' + rili_final['pos']

# %%
rili_final.head()
# Out:
#        0  1    2                X              nf pos             label
# 3112   1  1   re         gettonan       gettonare   V       gettonare+V
# 0      2  1    e      incidentali     incidentale   A     incidentale+A
# 18307  3  3  are        involtino       involtare   V       involtare+V
# 1459   4  1    o            lievi           lievo   N           lievo+N
# 3113   5  3   re  comunistizzasse  comunistizzare   V  comunistizzare+V

# %%
to_submit = rili_final[[0,'label']]

# %%
Id,Category

# %%
to_submit.columns = ['Id', 'Category']

# %%
print u'\xe0'
# Out:
# à

# %%
to_submit.head(10)
# Out:
#       Id          Category
# 5282   1       gettonare+V
# 0      2     incidentale+A
# 5283   3       involtare+V
# 3183   4           lievo+N
# 5284   5  comunistizzare+V
# 5285   6        vidimare+V
# 5286   7       imbrodare+V
# 5287   8       strillare+V
# 5288   9         cifrare+V
# 5289  10      compassare+V

# %%
to_submit.head(10)
# Out:
#        Id          Category
# 3112    1       gettonare+V
# 0       2     incidentale+A
# 18307   3       involtare+V
# 1459    4           lievo+N
# 3113    5  comunistizzare+V
# 18308   6       vidimeere+V
# 3114    7       imbrodare+V
# 3115    8       strillare+V
# 3116    9         cifrare+V
# 18309  10      compassare+V

# %%
to_submit['Category'].apply(lambda elem: elem.encode('utf-8'))
# Out:
# 3112           gettonare+V
# 0            incidentale+A
# 18307          involtare+V
# 1459               lievo+N
# 3113      comunistizzare+V
# 18308          vidimeere+V
# 3114           imbrodare+V
# 3115           strillare+V
# 3116             cifrare+V
# 18309         compassare+V
# 18310              cuere+V
# 3117            snobbare+V
# 3118             tessere+V
# 3119           coagulare+V
# 3120         somatizzare+V
# 1460       impoverimento+N
# 18311          smungeere+V
# 3121           abbuffare+V
# 18312       meravigliare+V
# 3122         risucchiare+V
# 1           sesquipedale+A
# 2                 timido+A
# 3123            nauseare+V
# 3124           ingozzare+V
# 18313            stimare+V
# 18314          relazione+V
# 3125           sorridere+V
# 3126          illuminare+V
# 18315         conciteere+V
# 18316          dissecare+V
#                ...
# 16126      diagnosticare+V
# 29646      condiscendrre+V
# 3108           banchetto+N
# ...

# %%
to_submit.to_csv('./my_snd_lemma.csv', index=False, encoding='utf-8')

# %%
vvvv_test['preds'] = resid_predicted
# Out:
# /Users/semenfedotov/anaconda2/envs/py27/lib/python2.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   """Entry point for launching an IPython kernel.

# %%
qoiwejoiqwej = asjkdqwjeoq.merge(to_submit, on='Id')

# %%
qoiwejoiqwej
# Out:
#           Id        Category_x         Category_y
# 0          1       gettonare+V        gettonare+V
# 1          2     incidentale+A      incidentale+A
# 2          3       involtare+V        involtare+V
# 3          4           lievo+N            lievo+N
# 4          5  comunistizzare+V   comunistizzare+V
# 5          6        vidimare+V        vidimeere+V
# 6          7       imbrodare+V        imbrodare+V
# 7          8       strillare+V        strillare+V
# 8          9         cifrare+V          cifrare+V
# 9         10      compassare+V       compassare+V
# 10        11          cucire+V            cuere+V
# 11        12        snobbare+V         snobbare+V
# 12        13         tessere+V          tessere+V
# 13        14       coagulare+V        coagulare+V
# 14        15     somatizzare+V      somatizzare+V
# 15        16   impoverimento+N    impoverimento+N
# 16        17        smungere+V        smungeere+V
# 17        18       abbuffare+V        abbuffare+V
# ...

# %%
asjkdqwjeoq = pd.read_csv('./my_fst_lemma.csv')

# %%
to_submit['Id']
# Out:
# 3112         1
# 0            2
# 18307        3
# 1459         4
# 3113         5
# 18308        6
# 3114         7
# 3115         8
# 3116         9
# 18309       10
# 18310       11
# 3117        12
# 3118        13
# 3119        14
# 3120        15
# 1460        16
# 18311       17
# 3121        18
# 18312       19
# 3122        20
# 1           21
# 2           22
# 3123        23
# 3124        24
# 18313       25
# 18314       26
# 3125        27
# 3126        28
# 18315       29
# 18316       30
#          ...
# 16126    29632
# 29646    29633
# 3108     29634
# 29647    29635
# 29648    29636
# 29649    29637
# 16127    29638
# 29650    29639
# 16128    29640
# 16129    29641
# 29651    29642
# 3109     29643
# 29652    29644
# 16130    29645
# 29653    29646
# 29654    29647
# 16131    29648
# 29655    29649
# 3110     29650
# 29656    29651
# 16132    29652
# 29657    29653
# 16133    29654
# 29658    29655
# 16134    29656
# 3111     29657
# 16135    29658
# ...

# %%
to_merge_vvv = vvvv_test[['Id', 'lenka', 'preds']].values

# %%
to_merge_vvv
# Out:
# array([[1, 1, 're'],
#        [5, 3, 're'],
#        [7, 1, 're'],
#        ...,
#        [29656, 3, 're'],
#        [29658, 1, 'are'],
#        [29659, 1, 're']], dtype=object)

# %%
vvvv_test
# Out:
#           Id                 X  vowels  consonal  length  doubles  2  lenka  \
# 0          1          gettonan       3         5       8        1  V      1
# 2          3         involtino       4         5       9        0  V      3
# 4          5   comunistizzasse       6         9      15        2  V      3
# 5          6       vidimerebbe       5         6      11        1  V      6
# 6          7          imbrodan       3         5       8        0  V      1
# 7          8          strillar       2         6       8        1  V      0
# 8          9          cifrasti       3         5       8        0  V      3
# 9         10      compassavano       5         7      12        1  V      4
# 10        11             cucio       3         2       5        0  V      1
# 11        12        snobbavate       4         6      10        1  V      4
# 12        13          tesseron       3         5       8        1  V      2
# ...

# %%
ansa
# Out:
#           Id pos
# 0          1   V
# 1          2   A
# 2          3   V
# 3          4   N
# 4          5   V
# 5          6   V
# 6          7   V
# 7          8   V
# 8          9   V
# 9         10   V
# 10        11   V
# 11        12   V
# 12        13   V
# 13        14   V
# 14        15   V
# 15        16   N
# 16        17   V
# 17        18   V
# 18        19   V
# 19        20   V
# 20        21   A
# 21        22   A
# 22        23   V
# 23        24   V
# 24        25   V
# 25        26   V
# 26        27   V
# 27        28   V
# 28        29   V
# 29        30   V
# ...      ...  ..
# 29631  29632   V
# 29632  29633   V
# 29633  29634   N
# 29634  29635   V
# 29635  29636   V
# 29636  29637   V
# 29637  29638   V
# 29638  29639   V
# 29639  29640   V
# 29640  29641   V
# 29641  29642   V
# 29642  29643   N
# 29643  29644   V
# 29644  29645   V
# 29645  29646   V
# 29646  29647   V
# 29647  29648   V
# 29648  29649   V
# 29649  29650   N
# 29650  29651   V
# ...

# %%
# ngram_vectorizer = CountVectorizer(analyzer='char_wb', ngram_range=(2, 3), min_df=1) 
# ngram_train = ngram_vectorizer.fit_transform(train.surname) 

from sklearn.cross_validation import train_test_split 
from sklearn.metrics import accuracy_score 
from sklearn import linear_model 


X_train, X_test, Y_train, Y_test = train_test_split(all_sparsed, v_tra_lem['lenka'], train_size=.8, random_state=42)#, stratify=v_tra_lem['resid'])

# %% [raw]
# FOR V
#
# LENKA____
#
#
# RESID AFTA LENKA ___
#
#
#
# TOTAL ___

# %% [raw]
# 0.988981998759 v 6
# 0.941660701503 a 5 + ply
# 0.93135345667 n 6 + poly
# ---------------------
# 0.900165528657 3 lenka
# 0.934409269605 4  eto v
# 0.947599834471 5
# 0.954117525347 6
# -------------
# afta gessing len
# 0.994568590937 v 4
# 0.996172149803 v 6

# %%
(len(v_tra_lem) * 0.988981998759 + len(a_tra_lem) * 0.941660701503 + len(n_tra_lem) * 0.93135345667 )/ len(train)
# Out:
# 0.9786198659989308

# %% [raw]
# label
#
# for a 0.939155332856 5
# for n 0.919182083739 6
# for n 0.920642648491 5

# %%
# %%time
lr = LogisticRegression(C=.65).fit(X_train, Y_train) 
print (accuracy_score(Y_test, lr.predict(X_test)))
# Out:
# 0.947599834471
# CPU times: user 49.8 s, sys: 153 ms, total: 49.9 s
# Wall time: 50.1 s

# %%
preds_0 = lr.predict(X_test)

# %%
# ngram_vectorizer = CountVectorizer(analyzer='char_wb', ngram_range=(2, 3), min_df=1) 
# ngram_train = ngram_vectorizer.fit_transform(train.surname) 

from sklearn.cross_validation import train_test_split 
from sklearn.metrics import accuracy_score 
from sklearn import linear_model 


X_train, X_test, Y_train, Y_test = train_test_split(all_sparsed, v_tra_lem['resid'], train_size=.8, random_state=42)#, stratify=v_tra_lem['resid'])

# %%
(1 - 0.996172149803) * X_test.shape[0]
# Out:
# 74.00000000840494

# %%
to_add = []
for word, stemmed in train_lem[[0,1]].values:
    to_add.append(stemmed[get_lcp(word, stemmed):])

train_lem['resid'] = to_add
# Out:
# /Users/semenfedotov/anaconda/lib/python2.7/site-packages/ipykernel/__main__.py:3: UnicodeWarning: Unicode equal comparison failed to convert both arguments to Unicode - interpreting them as being unequal
#   app.launch_new_instance()

# %%
sprsed_train_v = scipy.sparse.csr_matrix(train_lem.drop([0,1,2, 'resid'],axis=1).values)
# sprsed_train_v = scipy.sparse.csr_matrix(ntrrrr.values)



ngram_vectorizer = CountVectorizer(analyzer='char_wb', ngram_range=(2, 4), min_df=1) 
ngram_vectorizer.fit(train_lem[0])
# Out:
# CountVectorizer(analyzer='char_wb', binary=False, decode_error=u'strict',
#         dtype=<type 'numpy.int64'>, encoding=u'utf-8', input=u'content',
#         lowercase=True, max_df=1.0, max_features=None, min_df=1,
#         ngram_range=(2, 4), preprocessor=None, stop_words=None,
#         strip_accents=None, token_pattern=u'(?u)\\b\\w\\w+\\b',
#         tokenizer=None, vocabulary=None)

# %%
ngram_train = ngram_vectorizer.transform(train_lem[0])



all_sparsed = scipy.sparse.bmat([[ngram_train, sprsed_train_v]], format='csr')
all_sparsed
# Out:
# <120897x23132 sparse matrix of type '<type 'numpy.int64'>'
# 	with 4164263 stored elements in Compressed Sparse Row format>

# %%
test
# Out:
#           Id                 X
# 0          1          gettonan
# 1          2       incidentali
# 2          3         involtino
# 3          4             lievi
# 4          5   comunistizzasse
# 5          6       vidimerebbe
# 6          7          imbrodan
# 7          8          strillar
# 8          9          cifrasti
# 9         10      compassavano
# 10        11             cucio
# 11        12        snobbavate
# 12        13          tesseron
# 13        14         coagulare
# 14        15     somatizzarono
# 15        16     impoverimenti
# 16        17      smungerebber
# 17        18        abbufferan
# 18        19    meravigliavano
# 19        20         risucchiò
# 20        21      sesquipedale
# 21        22            timide
# 22        23       nauseassimo
# 23        24         ingozzavi
# 24        25           stimino
# 25        26        relazionai
# 26        27        sorridessi
# 27        28          illumini
# 28        29     conciterebber
# ...
